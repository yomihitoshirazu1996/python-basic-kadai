# %%
def fizz_buzz(var):
    if var % 3 == 0 and var % 5 == 0:
        return "FizzBuzz"
    elif var % 3 == 0:
        return "Fizz"
    elif var % 5 == 0:
        return "Buzz"
    else:
        return var


print(fizz_buzz(7))
print(fizz_buzz(15))
print(fizz_buzz(9))
print(fizz_buzz(10))
# Out:
# 7
# FizzBuzz
# Fizz
# Buzz
